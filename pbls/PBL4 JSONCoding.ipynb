# %% [markdown]
# 예수께서 나아와 말씀하여 이르시되 하늘과 땅의 모든 권세를 내게 주셨으니
# 그러므로 너희는 가서 모든 민족을 제자로 삼아 아버지와 아들과 성령의 이름으로 세례를 베풀고
# 내가 너희에게 분부한 모든 것을 가르쳐 지키게 하라 볼지어다 내가 세상 끝날까지 너희와 항상 함께 있으리라 하시니라 (마28:18-20)
#
# -------
# <center><img src="https://github.com/idebtor/DSpy/blob/6b3676c3de29f85d2e7f30679676d1fd96d88b17/images/WelcomeToDataStructures.jpg?raw=true" width=1000></center>
#
# __NOTE:__ The following materials have been compiled and adapted from the numerous sources including my own. Please help me to keep this tutorial up-to-date by reporting any issues or questions. Send any comments or criticisms to `idebtor@gmail.com` Your assistances and comments will be appreciated.
#
# --------

# %% [markdown]
# <b style="font-size:30px">Problem Set: JSON </b>
#
#
# Honor Code:

# %% [markdown]
# # JSON파일을 파이썬 객체화하기(디코딩, 역직렬화)
#
# - `json.load()`: 파일에 있는 JSON 포맷 데이터를 Python 객체로 읽어오기 (역직렬화 혹은 디코딩이라고 부르기도 합니다)
# - `json.loads()`: 메모리에 있는 JSON 형식의 문자열로 되어 있는 입력자료를 받아 파이썬 객체로 전환합니다.
#
# <img src="https://github.com/idebtor/DSpy/blob/b67467b971cf48c14faf7c8ebed7a94871dbb2ad/images/chap1/Chapter%201-25json_load.jpg?raw=true" width="100%">
# <center>그림1. load() and loads() 비교</center>

# %% [markdown]
# # 파이썬 객체로 JSON파일 만들기(인코딩, 직렬화)
#
# - `json.dump()`: Python객체를 파일에 저장할 때(직렬화, 인코딩) 사용합니다.
# - `json.dumps()`: Python객체를 문자열로 출력할 때 사용합니다.
#
# <img src="https://github.com/idebtor/DSpy/blob/b67467b971cf48c14faf7c8ebed7a94871dbb2ad/images/chap1/Chapter%201-27json_dump.jpg?raw=true" width="100%">
#
# <center>그림2. dump() and dumps() 비교</center>

# %% [markdown]
# # JSON Exercise - JSON file
#
# ## Code 편집기로 작성한 `companies.json`작성하기
#
# 코드(텍스트) 편집기를 사용하여 아래의 내용을 가진 파일(`companies.json`)을 작성하십시오.
# ```json
# [
#     {
#         "name": "Big Corpration",
#         "numberOfEmployee": 10000,
#         "ceo": "June",
#         "rating": 3.9
#     },
#     {
#         "name": "Small Start-up",
#         "numberOfEmployee": 5,
#         "ceo": null,
#         "rating": 4.5
#     }
# ]
# ```

# %% [markdown]
# ## Code 편집기로 작성한 companies.json을 읽고 출력하기
#
# - `with open()`을 사용하면, `close()`을 호출할 필요가 없습니다.
#
# __Sample Run:__
#
# ```json
# [{'name': 'Big Corpration', 'numberOfEmployee': 10000, 'ceo': 'June', 'rating': 3.9}, {'name': 'Small Start-up', 'numberOfEmployee': 5, 'ceo': None, 'rating': 4.5}]
# ```

# %%
import json

with open('companies.json') as file:
    companies = json.load(file)

print(companies)
# Out:
# [{'name': 'Big Corpration', 'numberOfEmployee': 10000, 'ceo': 'June', 'rating': 3.9}, {'name': 'Small Start-up', 'numberOfEmployee': 5, 'ceo': None, 'rating': 4.5}]

# %% [markdown]
# ## 자료를 하나씩 출력하기
#
# 각 회사(`company`)별로 출력합니다
#
# __Sample Run:__
#
# ```json
# {'name': 'Big Corpration', 'numberOfEmployee': 10000, 'ceo': 'June', 'rating': 3.9}
# {'name': 'Small Start-up', 'numberOfEmployee': 5, 'ceo': None, 'rating': 4.5}
# ```

# %%
for company in companies:
    print(company)
# Out:
# {'name': 'Big Corpration', 'numberOfEmployee': 10000, 'ceo': 'June', 'rating': 3.9}
# {'name': 'Small Start-up', 'numberOfEmployee': 5, 'ceo': None, 'rating': 4.5}

# %% [markdown]
# ## 자료를 정렬하고 읽기 쉽게 포맷하기
# - 각 회사의 자료에서 `numberOfEmployee`를 삭제하십시오.
# - `indent = 2`를 추가하고 필요에 따라 `sort_keys = True` 추가합니다.
# - 아래와 같이 출력하십시오.

# %% [markdown]
# __Sample Run:__
# ```json
# [
#   {
#     "ceo": "June",
#     "name": "Big Corpration",
#     "rating": 3.9
#   },
#   {
#     "ceo": null,
#     "name": "Small Start-up",
#     "rating": 4.5
#   }
# ]
# ```

# %%
for company in companies:
    del company['numberOfEmployee']


sorted = json.dumps(companies,indent = 2, sort_keys = True)
print(sorted)
# Out:
# [
#   {
#     "ceo": "June",
#     "name": "Big Corpration",
#     "rating": 3.9
#   },
#   {
#     "ceo": null,
#     "name": "Small Start-up",
#     "rating": 4.5
#   }
# ]

# %% [markdown]
# ## 새로운 JSON 파일(`companies_new.json`)에 저장하기
# 아래와 같은 내용으로 JSON파일(`companies_new.json`)을 작성하십시오.
#
# __Sample Run:__ Expected JSON File
# ```json
# [
#   {
#     "ceo": "June",
#     "name": "Big Corpration",
#     "rating": 3.9
#   },
#   {
#     "ceo": null,
#     "name": "Small Start-up",
#     "rating": 4.5
#   }
# ]
# ```
# - 가독성(readability)를 높이기 위하여 `indent = 2`를 인자로 사용하는 것이 좋습니다.
# - `with open()`을 사용하면, `close()`을 호출할 필요가 없습니다.

# %%
companies = json.loads(companies)

# %% [markdown]
# __Solution__

# %%
import json

with open('companies_new.json','w') as file:
    json.dump(companies,file,indent = 2)

# %% [markdown]
# ## 위에서 작성한 파일을 읽고 확인하기
#
# __Sample Run:__
#
# ```json
# {'ceo': 'June', 'name': 'Big Corpration', 'rating': 3.9}
# {'ceo': None, 'name': 'Small Start-up', 'rating': 4.5}
# [
#   {
#     "ceo": "June",
#     "name": "Big Corpration",
#     "rating": 3.9
#   },
#   {
#     "ceo": null,
#     "name": "Small Start-up",
#     "rating": 4.5
#   }
# ]
# ```

# %%
import json
with open('companies_new.json','r') as file:
    companies = json.load(file)
for company in companies:
    print(company)

print(json.dumps(companies,indent = 2))
# Out:
# {'ceo': 'June', 'name': 'Big Corpration', 'rating': 3.9}
# {'ceo': None, 'name': 'Small Start-up', 'rating': 4.5}
# [
#   {
#     "ceo": "June",
#     "name": "Big Corpration",
#     "rating": 3.9
#   },
#   {
#     "ceo": null,
#     "name": "Small Start-up",
#     "rating": 4.5
#   }
# ]

# %% [markdown]
# # JSON Exercise: Exchange Rate Extraction
#
# 지금까지 경험해 본 JSON과 파이썬 코딩을 활용하여, 실생활 데이터를 가지고 응용하는 문제를 다루어 보도록 하겠습니다.
#
# 이제는 대부분의 자료 제공자들이 JSON 파일 형식으로 자료를 제공합니다. 여기 연습문제로 무료로 140 여개의 환율 정보를 제공하는 Website에서 JSON 파일로 원화(KRW)에 대한 각 국가의 환율 정보를 가져옵니다. 그러한 환율 정보 중에서 몇 개의 특정한 통화를 계산해보는 응용 문제를 시도해봅니다.

# %% [markdown]
# ## JSON 파일을 다운받아 파이썬 객체로 변환하기
# - 파일을 읽을 때는 `load()`를 사용하고, 문자열(String)을 읽을 때는`loads()`를 사용합니다.

# %%
import json
from urllib.request import urlopen

with urlopen("http://www.floatrates.com/daily/krw.json") as response:
    source = response.read()

rates = json.loads(source)

# %% [markdown]
# ## 파이썬 객체로 변환한 것을 출력하기
# - 가독성을 위해 `ident = 2`로 설정하는 것이 필요합니다.
#
# __Sample Run:__
# ```json
# {
#   "usd": {
#     "code": "USD",
#     "alphaCode": "USD",
#     "numericCode": "840",
#     "name": "U.S. Dollar",
#     "rate": 0.00086484208312665,
#     "date": "Sat, 4 Sep 2021 23:55:01 GMT",
#     "inverseRate": 1156.2804580285
#   },
#   "eur": {
#     "code": "EUR",
#     "alphaCode": "EUR",
#     "numericCode": "978",
#     "name": "Euro",
#   ...
# }
# ```

# %%
print(json.dumps(rates,indent = 2))
# Out:
# {
#   "aud": {
#     "code": "AUD",
#     "alphaCode": "AUD",
#     "numericCode": "036",
#     "name": "Australian Dollar",
#     "rate": 0.0011404563098539,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 876.8420073261
#   },
#   "cad": {
#     "code": "CAD",
#     "alphaCode": "CAD",
#     "numericCode": "124",
#     "name": "Canadian Dollar",
#     "rate": 0.0010160876357253,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 984.16707854747
#   },
#   "cny": {
#     "code": "CNY",
#     "alphaCode": "CNY",
#     "numericCode": "156",
#     "name": "Chinese Yuan",
#     "rate": 0.0054177233448891,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 184.57937704467
#   },
#   "eur": {
#     "code": "EUR",
#     "alphaCode": "EUR",
#     "numericCode": "978",
#     "name": "Euro",
#     "rate": 0.00069002910115574,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 1449.2142408561
#   },
#   "gbp": {
#     "code": "GBP",
#     "alphaCode": "GBP",
#     "numericCode": "826",
#     "name": "U.K. Pound Sterling",
#     "rate": 0.00059054470357732,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 1693.3519070484
#   },
#   "hkd": {
#     "code": "HKD",
#     "alphaCode": "HKD",
#     "numericCode": "344",
#     "name": "Hong Kong Dollar",
#     "rate": 0.0058862863944225,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 169.8863991646
#   },
#   "idr": {
#     "code": "IDR",
#     "alphaCode": "IDR",
#     "numericCode": "360",
#     "name": "Indonesian Rupiah",
#     "rate": 11.805456443962,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.084706593493171
#   },
#   "inr": {
#     "code": "INR",
#     "alphaCode": "INR",
#     "numericCode": "356",
#     "name": "Indian Rupee",
#     "rate": 0.06257077601878,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 15.981901833851
#   },
#   "jpy": {
#     "code": "JPY",
#     "alphaCode": "JPY",
#     "numericCode": "392",
#     "name": "Japanese Yen",
#     "rate": 0.11378271618643,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 8.7886810362436
#   },
#   "myr": {
#     "code": "MYR",
#     "alphaCode": "MYR",
#     "numericCode": "458",
#     "name": "Malaysian Ringgit",
#     "rate": 0.00354789898619,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 281.85695362028
#   },
#   "nzd": {
#     "code": "NZD",
#     "alphaCode": "NZD",
#     "numericCode": "554",
#     "name": "New Zealand Dollar",
#     "rate": 0.0012392891187765,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 806.91420980703
#   },
#   "php": {
#     "code": "PHP",
#     "alphaCode": "PHP",
#     "numericCode": "608",
#     "name": "Philippine Peso",
#     "rate": 0.042127573389606,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 23.737422299446
#   },
#   "sgd": {
#     "code": "SGD",
#     "alphaCode": "SGD",
#     "numericCode": "702",
#     "name": "Singapore Dollar",
#     "rate": 0.0010086312378278,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 991.44262292884
#   },
#   "thb": {
#     "code": "THB",
#     "alphaCode": "THB",
#     "numericCode": "764",
#     "name": "Thai Baht",
#     "rate": 0.027144635137655,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 36.839692076495
#   },
#   "twd": {
#     "code": "TWD",
#     "alphaCode": "TWD",
#     "numericCode": "901",
#     "name": "New Taiwan Dollar ",
#     "rate": 0.023992984216366,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 41.678850408191
#   },
#   "usd": {
#     "code": "USD",
#     "alphaCode": "USD",
#     "numericCode": "840",
#     "name": "U.S. Dollar",
#     "rate": 0.00075260710505586,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 1328.714535489
#   },
#   "vnd": {
#     "code": "VND",
#     "alphaCode": "VND",
#     "numericCode": "704",
#     "name": "Vietnamese Dong",
#     "rate": 18.663325353486,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.053581019516075
#   },
#   "aed": {
#     "code": "AED",
#     "alphaCode": "AED",
#     "numericCode": "784",
#     "name": "U.A.E Dirham",
#     "rate": 0.0027943019494094,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 357.87113136122
#   },
#   "bgn": {
#     "code": "BGN",
#     "alphaCode": "BGN",
#     "numericCode": "975",
#     "name": "Bulgarian Lev",
#     "rate": 0.0013494436266574,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 741.046146905
#   },
#   "brl": {
#     "code": "BRL",
#     "alphaCode": "BRL",
#     "numericCode": "986",
#     "name": "Brazilian Real",
#     "rate": 0.0037448189081546,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 267.03560960516
#   },
#   "chf": {
#     "code": "CHF",
#     "alphaCode": "CHF",
#     "numericCode": "756",
#     "name": "Swiss Franc",
#     "rate": 0.00067410461329376,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 1483.4492752006
#   },
#   "czk": {
#     "code": "CZK",
#     "alphaCode": "CZK",
#     "numericCode": "203",
#     "name": "Czech Koruna",
#     "rate": 0.017416442044813,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 57.417008446786
#   },
#   "dkk": {
#     "code": "DKK",
#     "alphaCode": "DKK",
#     "numericCode": "208",
#     "name": "Danish Krone",
#     "rate": 0.005145845359843,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 194.33152962656
#   },
#   "egp": {
#     "code": "EGP",
#     "alphaCode": "EGP",
#     "numericCode": "818",
#     "name": "Egyptian Pound",
#     "rate": 0.035123806676502,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 28.470718143117
#   },
#   "huf": {
#     "code": "HUF",
#     "alphaCode": "HUF",
#     "numericCode": "348",
#     "name": "Hungarian Forint",
#     "rate": 0.27143218571125,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 3.6841614688385
#   },
#   "mdl": {
#     "code": "MDL",
#     "alphaCode": "MDL",
#     "numericCode": "498",
#     "name": "Moldova Lei",
#     "rate": 0.013288862495703,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 75.250985577084
#   },
#   "mxn": {
#     "code": "MXN",
#     "alphaCode": "MXN",
#     "numericCode": "484",
#     "name": "Mexican Peso",
#     "rate": 0.012602576705436,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 79.348852490513
#   },
#   "nok": {
#     "code": "NOK",
#     "alphaCode": "NOK",
#     "numericCode": "578",
#     "name": "Norwegian Krone",
#     "rate": 0.0079828745246461,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 125.26815959748
#   },
#   "pln": {
#     "code": "PLN",
#     "alphaCode": "PLN",
#     "numericCode": "985",
#     "name": "Polish Zloty",
#     "rate": 0.0029688103980838,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 336.83525247872
#   },
#   "ron": {
#     "code": "RON",
#     "alphaCode": "RON",
#     "numericCode": "946",
#     "name": "Romanian New Leu",
#     "rate": 0.0034315160949082,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 291.41638049836
#   },
#   "rsd": {
#     "code": "RSD",
#     "alphaCode": "RSD",
#     "numericCode": "941",
#     "name": "Serbian Dinar",
#     "rate": 0.082089504893803,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 12.181825207664
#   },
#   "rub": {
#     "code": "RUB",
#     "alphaCode": "RUB",
#     "numericCode": "643",
#     "name": "Russian Rouble",
#     "rate": 0.069186747820647,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 14.453635002361
#   },
#   "sek": {
#     "code": "SEK",
#     "alphaCode": "SEK",
#     "numericCode": "752",
#     "name": "Swedish Krona",
#     "rate": 0.0078521261812919,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 127.35404104719
#   },
#   "try": {
#     "code": "TRY",
#     "alphaCode": "TRY",
#     "numericCode": "949",
#     "name": "Turkish Lira",
#     "rate": 0.024103681964391,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 41.487437540759
#   },
#   "uah": {
#     "code": "UAH",
#     "alphaCode": "UAH",
#     "numericCode": "980",
#     "name": "Ukrainian Hryvnia",
#     "rate": 0.029307421509451,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 34.121050181011
#   },
#   "zar": {
#     "code": "ZAR",
#     "alphaCode": "ZAR",
#     "numericCode": "710",
#     "name": "South African Rand",
#     "rate": 0.0141206649457,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 70.818194741211
#   },
#   "clp": {
#     "code": "CLP",
#     "alphaCode": "CLP",
#     "numericCode": "152",
#     "name": "Chilean Peso",
#     "rate": 0.72528960298393,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 1.3787595960095
#   },
#   "ils": {
#     "code": "ILS",
#     "alphaCode": "ILS",
#     "numericCode": "376",
#     "name": "Israeli New Sheqel",
#     "rate": 0.0027052461394412,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 369.65213088025
#   },
#   "isk": {
#     "code": "ISK",
#     "alphaCode": "ISK",
#     "numericCode": "352",
#     "name": "Icelandic Krona",
#     "rate": 0.10259969665275,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 9.7466175108154
#   },
#   "amd": {
#     "code": "AMD",
#     "alphaCode": "AMD",
#     "numericCode": "051",
#     "name": "Armenia Dram",
#     "rate": 0.31116191571349,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 3.2137609054984
#   },
#   "azn": {
#     "code": "AZN",
#     "alphaCode": "AZN",
#     "numericCode": "944",
#     "name": "Azerbaijan Manat",
#     "rate": 0.0012791313840985,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 781.78052108761
#   },
#   "bdt": {
#     "code": "BDT",
#     "alphaCode": "BDT",
#     "numericCode": "050",
#     "name": "Bangladeshi taka",
#     "rate": 0.083656454159061,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 11.953650319659
#   },
#   "dop": {
#     "code": "DOP",
#     "alphaCode": "DOP",
#     "numericCode": "214",
#     "name": "Dominican Peso",
#     "rate": 0.044952693496861,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 22.245608042816
#   },
#   "dzd": {
#     "code": "DZD",
#     "alphaCode": "DZD",
#     "numericCode": "012",
#     "name": "Algerian Dinar",
#     "rate": 0.10322825423821,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 9.6872702864124
#   },
#   "gel": {
#     "code": "GEL",
#     "alphaCode": "GEL",
#     "numericCode": "981",
#     "name": "Georgian lari",
#     "rate": 0.0020450867693559,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 488.97680772487
#   },
#   "iqd": {
#     "code": "IQD",
#     "alphaCode": "IQD",
#     "numericCode": "368",
#     "name": "Iraqi dinar",
#     "rate": 1.0085738472347,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.9914990387088
#   },
#   "irr": {
#     "code": "IRR",
#     "alphaCode": "IRR",
#     "numericCode": "364",
#     "name": "Iranian rial",
#     "rate": 32.335861924135,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.030925416565241
#   },
#   "kgs": {
#     "code": "KGS",
#     "alphaCode": "KGS",
#     "numericCode": "417",
#     "name": "Kyrgyzstan Som",
#     "rate": 0.068844509865645,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 14.525486519573
#   },
#   "kzt": {
#     "code": "KZT",
#     "alphaCode": "KZT",
#     "numericCode": "398",
#     "name": "Kazakhstani Tenge",
#     "rate": 0.33903554688359,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 2.9495432239834
#   },
#   "lyd": {
#     "code": "LYD",
#     "alphaCode": "LYD",
#     "numericCode": "434",
#     "name": "Libyan Dinar",
#     "rate": 0.0037193097423798,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 268.86709343013
#   },
#   "mad": {
#     "code": "MAD",
#     "alphaCode": "MAD",
#     "numericCode": "504",
#     "name": "Moroccan Dirham",
#     "rate": 0.0077672086419011,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 128.74638059874
#   },
#   "pkr": {
#     "code": "PKR",
#     "alphaCode": "PKR",
#     "numericCode": "586",
#     "name": "Pakistani Rupee",
#     "rate": 0.21185436118464,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 4.7202238103962
#   },
#   "sar": {
#     "code": "SAR",
#     "alphaCode": "SAR",
#     "numericCode": "682",
#     "name": "Saudi Riyal",
#     "rate": 0.0028258572794228,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 353.87491338708
#   },
#   "tjs": {
#     "code": "TJS",
#     "alphaCode": "TJS",
#     "numericCode": "972",
#     "name": "Tajikistan Ruble",
#     "rate": 0.0084340619563328,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 118.56683116362
#   },
#   "tmt": {
#     "code": "TMT",
#     "alphaCode": "TMT",
#     "numericCode": "934",
#     "name": "New Turkmenistan Manat",
#     "rate": 0.0026946452455047,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 371.10636424896
#   },
#   "tnd": {
#     "code": "TND",
#     "alphaCode": "TND",
#     "numericCode": "788",
#     "name": "Tunisian Dinar",
#     "rate": 0.002395988590086,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 417.36425796756
#   },
#   "uzs": {
#     "code": "UZS",
#     "alphaCode": "UZS",
#     "numericCode": "860",
#     "name": "Uzbekistan Sum",
#     "rate": 9.6213181571028,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.10393586239135
#   },
#   "jod": {
#     "code": "JOD",
#     "alphaCode": "JOD",
#     "numericCode": "400",
#     "name": "Jordanian Dinar",
#     "rate": 0.00053365258752656,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 1873.8782934323
#   },
#   "lbp": {
#     "code": "LBP",
#     "alphaCode": "LBP",
#     "numericCode": "422",
#     "name": "Lebanese Pound",
#     "rate": 67.809900165533,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.01474710916192
#   },
#   "byn": {
#     "code": "BYN",
#     "alphaCode": "BYN",
#     "numericCode": "933",
#     "name": "Belarussian Ruble",
#     "rate": 0.0024629445108125,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 406.01807942076
#   },
#   "xaf": {
#     "code": "XAF",
#     "alphaCode": "XAF",
#     "numericCode": "950",
#     "name": "Central African CFA Franc",
#     "rate": 0.45262482700204,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 2.2093352824314
#   },
#   "xof": {
#     "code": "XOF",
#     "alphaCode": "XOF",
#     "numericCode": "952",
#     "name": "West African CFA Franc",
#     "rate": 0.45262482700204,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 2.2093352824314
#   },
#   "pen": {
#     "code": "PEN",
#     "alphaCode": "PEN",
#     "numericCode": "604",
#     "name": "Peruvian Nuevo Sol",
#     "rate": 0.0027803652626004,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 359.66497404184
#   },
#   "ars": {
#     "code": "ARS",
#     "alphaCode": "ARS",
#     "numericCode": "032",
#     "name": "Argentine Peso",
#     "rate": 0.64294953184098,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 1.5553320291511
#   },
#   "bob": {
#     "code": "BOB",
#     "alphaCode": "BOB",
#     "numericCode": "068",
#     "name": "Bolivian Boliviano",
#     "rate": 0.005162884740683,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 193.69016552318
#   },
#   "cop": {
#     "code": "COP",
#     "alphaCode": "COP",
#     "numericCode": "170",
#     "name": "Colombian Peso",
#     "rate": 2.9334572390245,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.3408946913208
#   },
#   "crc": {
#     "code": "CRC",
#     "alphaCode": "CRC",
#     "numericCode": "188",
#     "name": "Costa Rican Col\u00f3n",
#     "rate": 0.37939975129908,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 2.6357423708792
#   },
#   "htg": {
#     "code": "HTG",
#     "alphaCode": "HTG",
#     "numericCode": "332",
#     "name": "Haitian gourde",
#     "rate": 0.099573476194463,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 10.042835082377
#   },
#   "pab": {
#     "code": "PAB",
#     "alphaCode": "PAB",
#     "numericCode": "590",
#     "name": "Panamanian Balboa",
#     "rate": 0.00075260710505586,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 1328.714535489
#   },
#   "pyg": {
#     "code": "PYG",
#     "alphaCode": "PYG",
#     "numericCode": "600",
#     "name": "Paraguayan Guaran\u00ed",
#     "rate": 5.5514889684764,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.18013185393656
#   },
#   "uyu": {
#     "code": "UYU",
#     "alphaCode": "UYU",
#     "numericCode": "858",
#     "name": "Uruguayan Peso",
#     "rate": 0.028719390002131,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 34.819681056102
#   },
#   "ves": {
#     "code": "VES",
#     "alphaCode": "VES",
#     "numericCode": "928",
#     "name": "Venezuelan Bolivar",
#     "rate": 0.02726439410468,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 36.677873572417
#   },
#   "afn": {
#     "code": "AFN",
#     "alphaCode": "AFN",
#     "numericCode": "971",
#     "name": "Afghan afghani",
#     "rate": 0.053808710494989,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 18.584351693266
#   },
#   "all": {
#     "code": "ALL",
#     "alphaCode": "ALL",
#     "numericCode": "008",
#     "name": "Albanian lek",
#     "rate": 0.071526181466967,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 13.980894540859
#   },
#   "ang": {
#     "code": "ANG",
#     "alphaCode": "ANG",
#     "numericCode": "532",
#     "name": "Neth. Antillean Guilder",
#     "rate": 0.001357994593225,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 736.37995687832
#   },
#   "aoa": {
#     "code": "AOA",
#     "alphaCode": "AOA",
#     "numericCode": "973",
#     "name": "Angolan kwanza",
#     "rate": 0.64156539436332,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 1.5586875613707
#   },
#   "awg": {
#     "code": "AWG",
#     "alphaCode": "AWG",
#     "numericCode": "533",
#     "name": "Aruban florin",
#     "rate": 0.0013637307742292,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 733.28256492945
#   },
#   "bam": {
#     "code": "BAM",
#     "alphaCode": "BAM",
#     "numericCode": "977",
#     "name": "Bosnia and Herzegovina convertible mark",
#     "rate": 0.0013614428428496,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 734.51486065104
#   },
#   "bbd": {
#     "code": "BBD",
#     "alphaCode": "BBD",
#     "numericCode": "052",
#     "name": "Barbadian Dollar",
#     "rate": 0.0015214218624882,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 657.27989366774
#   },
#   "bhd": {
#     "code": "BHD",
#     "alphaCode": "BHD",
#     "numericCode": "048",
#     "name": "Bahrain Dinar",
#     "rate": 0.00028402618841773,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 3520.8020977602
#   },
#   "bif": {
#     "code": "BIF",
#     "alphaCode": "BIF",
#     "numericCode": "108",
#     "name": "Burundian franc",
#     "rate": 2.1554386544296,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.46394268653619
#   },
#   "bnd": {
#     "code": "BND",
#     "alphaCode": "BND",
#     "numericCode": "096",
#     "name": "Brunei Dollar",
#     "rate": 0.0010124855996022,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 987.66836821469
#   },
#   "bsd": {
#     "code": "BSD",
#     "alphaCode": "BSD",
#     "numericCode": "044",
#     "name": "Bahamian Dollar",
#     "rate": 0.00075260710505586,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 1328.714535489
#   },
#   "bwp": {
#     "code": "BWP",
#     "alphaCode": "BWP",
#     "numericCode": "072",
#     "name": "Botswana Pula",
#     "rate": 0.010328606968078,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 96.818477369755
#   },
#   "bzd": {
#     "code": "BZD",
#     "alphaCode": "BZD",
#     "numericCode": "084",
#     "name": "Belize dollar",
#     "rate": 0.0015188052231374,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 658.41227352002
#   },
#   "cdf": {
#     "code": "CDF",
#     "alphaCode": "CDF",
#     "numericCode": "976",
#     "name": "Congolese franc",
#     "rate": 2.0908955749446,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.47826396113852
#   },
#   "cup": {
#     "code": "CUP",
#     "alphaCode": "CUP",
#     "numericCode": "192",
#     "name": "Cuban peso",
#     "rate": 0.00075260710505586,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 1328.714535489
#   },
#   "cve": {
#     "code": "CVE",
#     "alphaCode": "CVE",
#     "numericCode": "132",
#     "name": "Cape Verde escudo",
#     "rate": 0.076987847323601,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 12.989063011422
#   },
#   "djf": {
#     "code": "DJF",
#     "alphaCode": "DJF",
#     "numericCode": "262",
#     "name": "Djiboutian franc",
#     "rate": 0.13408923033317,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 7.4577204859427
#   },
#   "ern": {
#     "code": "ERN",
#     "alphaCode": "ERN",
#     "numericCode": "232",
#     "name": "Eritrean nakfa",
#     "rate": 0.011360295291791,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 88.025880869717
#   },
#   "etb": {
#     "code": "ETB",
#     "alphaCode": "ETB",
#     "numericCode": "230",
#     "name": "Ethiopian birr",
#     "rate": 0.042832040593729,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 23.347008130787
#   },
#   "fjd": {
#     "code": "FJD",
#     "alphaCode": "FJD",
#     "numericCode": "242",
#     "name": "Fiji Dollar",
#     "rate": 0.0017139662322299,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 583.44206624128
#   },
#   "ghs": {
#     "code": "GHS",
#     "alphaCode": "GHS",
#     "numericCode": "936",
#     "name": "Ghanaian Cedi",
#     "rate": 0.0097961698062655,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 102.08071315387
#   },
#   "gip": {
#     "code": "GIP",
#     "alphaCode": "GIP",
#     "numericCode": "292",
#     "name": "Gibraltar pound",
#     "rate": 0.00059297443381462,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 1686.4133476497
#   },
#   "gmd": {
#     "code": "GMD",
#     "alphaCode": "GMD",
#     "numericCode": "270",
#     "name": "Gambian dalasi",
#     "rate": 0.051237645829699,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 19.516899806907
#   },
#   "gnf": {
#     "code": "GNF",
#     "alphaCode": "GNF",
#     "numericCode": "324",
#     "name": "Guinean franc",
#     "rate": 6.4709613052163,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.15453654454615
#   },
#   "gtq": {
#     "code": "GTQ",
#     "alphaCode": "GTQ",
#     "numericCode": "320",
#     "name": "Guatemalan Quetzal",
#     "rate": 0.0058769349101984,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 170.15672544963
#   },
#   "gyd": {
#     "code": "GYD",
#     "alphaCode": "GYD",
#     "numericCode": "328",
#     "name": "Guyanese dollar",
#     "rate": 0.15777027195735,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 6.3383296966764
#   },
#   "hnl": {
#     "code": "HNL",
#     "alphaCode": "HNL",
#     "numericCode": "340",
#     "name": "Honduran Lempira",
#     "rate": 0.01860301143507,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 53.754737693425
#   },
#   "jmd": {
#     "code": "JMD",
#     "alphaCode": "JMD",
#     "numericCode": "388",
#     "name": "Jamaican Dollar",
#     "rate": 0.11592764654905,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 8.6260700511753
#   },
#   "kes": {
#     "code": "KES",
#     "alphaCode": "KES",
#     "numericCode": "404",
#     "name": "Kenyan shilling",
#     "rate": 0.099841254468142,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 10.015899793397
#   },
#   "khr": {
#     "code": "KHR",
#     "alphaCode": "KHR",
#     "numericCode": "116",
#     "name": "Cambodian riel",
#     "rate": 3.0513476073377,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.32772405136513
#   },
#   "kmf": {
#     "code": "KMF",
#     "alphaCode": "KMF",
#     "numericCode": "174",
#     "name": "\tComoro franc",
#     "rate": 0.34224621516248,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 2.9218730717746
#   },
#   "kwd": {
#     "code": "KWD",
#     "alphaCode": "KWD",
#     "numericCode": "414",
#     "name": "Kuwaiti Dinar",
#     "rate": 0.00023174076484366,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 4315.1665641332
#   },
#   "lak": {
#     "code": "LAK",
#     "alphaCode": "LAK",
#     "numericCode": "418",
#     "name": "Lao kip",
#     "rate": 15.80276866116,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.063280050568468
#   },
#   "lkr": {
#     "code": "LKR",
#     "alphaCode": "LKR",
#     "numericCode": "144",
#     "name": "Sri Lanka Rupee",
#     "rate": 0.22932300050564,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 4.3606615899629
#   },
#   "lrd": {
#     "code": "LRD",
#     "alphaCode": "LRD",
#     "numericCode": "430",
#     "name": "Liberian dollar",
#     "rate": 0.14646468515221,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 6.82758440344
#   },
#   "lsl": {
#     "code": "LSL",
#     "alphaCode": "LSL",
#     "numericCode": "426",
#     "name": "Lesotho loti",
#     "rate": 0.014277346864576,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 70.041024392362
#   },
#   "mga": {
#     "code": "MGA",
#     "alphaCode": "MGA",
#     "numericCode": "969",
#     "name": "Malagasy ariary",
#     "rate": 3.3774196238699,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.29608402608089
#   },
#   "mkd": {
#     "code": "MKD",
#     "alphaCode": "MKD",
#     "numericCode": "807",
#     "name": "Macedonian denar",
#     "rate": 0.042716869575901,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 23.409955128457
#   },
#   "mmk": {
#     "code": "MMK",
#     "alphaCode": "MMK",
#     "numericCode": "104",
#     "name": "Myanma Kyat",
#     "rate": 1.582775986094,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.6318013469915
#   },
#   "mnt": {
#     "code": "MNT",
#     "alphaCode": "MNT",
#     "numericCode": "496",
#     "name": "Mongolian togrog",
#     "rate": 2.561882291485,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.39033799613813
#   },
#   "mop": {
#     "code": "MOP",
#     "alphaCode": "MOP",
#     "numericCode": "446",
#     "name": "Macanese pataca",
#     "rate": 0.006074299100992,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 164.62804734734
#   },
#   "mru": {
#     "code": "MRU",
#     "alphaCode": "MRU",
#     "numericCode": "929",
#     "name": "Mauritanian ouguiya",
#     "rate": 0.030115607278037,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 33.205373903561
#   },
#   "mur": {
#     "code": "MUR",
#     "alphaCode": "MUR",
#     "numericCode": "480",
#     "name": "Mauritian Rupee",
#     "rate": 0.034751458861347,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 28.775770363767
#   },
#   "mvr": {
#     "code": "MVR",
#     "alphaCode": "MVR",
#     "numericCode": "462",
#     "name": "Maldivian rufiyaa",
#     "rate": 0.011651245811488,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 85.827731744706
#   },
#   "mwk": {
#     "code": "MWK",
#     "alphaCode": "MWK",
#     "numericCode": "454",
#     "name": "Malawian kwacha",
#     "rate": 1.2684943158514,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.78833620892402
#   },
#   "mzn": {
#     "code": "MZN",
#     "alphaCode": "MZN",
#     "numericCode": "943",
#     "name": "Mozambican metical",
#     "rate": 0.04811740457725,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 20.782500818276
#   },
#   "nad": {
#     "code": "NAD",
#     "alphaCode": "NAD",
#     "numericCode": "516",
#     "name": "Namibian dollar",
#     "rate": 0.014284139132352,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 70.007719102589
#   },
#   "ngn": {
#     "code": "NGN",
#     "alphaCode": "NGN",
#     "numericCode": "566",
#     "name": "Nigerian Naira",
#     "rate": 1.1085769161102,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.90205739039638
#   },
#   "nio": {
#     "code": "NIO",
#     "alphaCode": "NIO",
#     "numericCode": "558",
#     "name": "Nicaraguan C\u00f3rdoba",
#     "rate": 0.027724155545895,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 36.069628824027
#   },
#   "npr": {
#     "code": "NPR",
#     "alphaCode": "NPR",
#     "numericCode": "524",
#     "name": "Nepalese Rupee",
#     "rate": 0.10022451584286,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 9.9775987101588
#   },
#   "omr": {
#     "code": "OMR",
#     "alphaCode": "OMR",
#     "numericCode": "512",
#     "name": "Omani Rial",
#     "rate": 0.00029011314997057,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 3446.930965044
#   },
#   "pgk": {
#     "code": "PGK",
#     "alphaCode": "PGK",
#     "numericCode": "598",
#     "name": "Papua New Guinean kina",
#     "rate": 0.0028403424894716,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 352.07021818909
#   },
#   "qar": {
#     "code": "QAR",
#     "alphaCode": "QAR",
#     "numericCode": "634",
#     "name": "Qatari Rial",
#     "rate": 0.0027480560549335,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 363.89359605846
#   },
#   "rwf": {
#     "code": "RWF",
#     "alphaCode": "RWF",
#     "numericCode": "646",
#     "name": "Rwandan franc",
#     "rate": 0.96886932740251,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 1.0321309300615
#   },
#   "sbd": {
#     "code": "SBD",
#     "alphaCode": "SBD",
#     "numericCode": "090",
#     "name": "Solomon Islands dollar",
#     "rate": 0.0063331070356895,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 157.90037881321
#   },
#   "scr": {
#     "code": "SCR",
#     "alphaCode": "SCR",
#     "numericCode": "690",
#     "name": "Seychelles rupee",
#     "rate": 0.010106112573613,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 98.950015915221
#   },
#   "sdg": {
#     "code": "SDG",
#     "alphaCode": "SDG",
#     "numericCode": "938",
#     "name": "Sudanese pound",
#     "rate": 0.4523920514721,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 2.2104720822259
#   },
#   "sos": {
#     "code": "SOS",
#     "alphaCode": "SOS",
#     "numericCode": "706",
#     "name": "Somali shilling",
#     "rate": 0.43065491187899,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 2.3220448029651
#   },
#   "srd": {
#     "code": "SRD",
#     "alphaCode": "SRD",
#     "numericCode": "968",
#     "name": "Surinamese dollar",
#     "rate": 0.026641757281459,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 37.535061574033
#   },
#   "ssp": {
#     "code": "SSP",
#     "alphaCode": "SSP",
#     "numericCode": "728",
#     "name": "South Sudanese pound",
#     "rate": 1.1938473342427,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.83762803778787
#   },
#   "stn": {
#     "code": "STN",
#     "alphaCode": "STN",
#     "numericCode": "930",
#     "name": "S\u00e3o Tom\u00e9 and Pr\u00edncipe Dobra",
#     "rate": 0.017186754697312,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 58.184341233218
#   },
#   "svc": {
#     "code": "SVC",
#     "alphaCode": "SVC",
#     "numericCode": "222",
#     "name": "Salvadoran colon",
#     "rate": 0.0065960589754403,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 151.60567904614
#   },
#   "syp": {
#     "code": "SYP",
#     "alphaCode": "SYP",
#     "numericCode": "760",
#     "name": "Syrian pound",
#     "rate": 9.8121766196746,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.101914186705
#   },
#   "szl": {
#     "code": "SZL",
#     "alphaCode": "SZL",
#     "numericCode": "748",
#     "name": "Swazi lilangeni",
#     "rate": 0.014277346864576,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 70.041024392362
#   },
#   "top": {
#     "code": "TOP",
#     "alphaCode": "TOP",
#     "numericCode": "776",
#     "name": "Tongan pa\u02bbanga",
#     "rate": 0.0017810689557601,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 561.46057499118
#   },
#   "ttd": {
#     "code": "TTD",
#     "alphaCode": "TTD",
#     "numericCode": "780",
#     "name": "Trinidad Tobago Dollar",
#     "rate": 0.0051054685353178,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 195.86840915429
#   },
#   "tzs": {
#     "code": "TZS",
#     "alphaCode": "TZS",
#     "numericCode": "834",
#     "name": "Tanzanian shilling",
#     "rate": 1.92469618309,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.5195625204569
#   },
#   "ugx": {
#     "code": "UGX",
#     "alphaCode": "UGX",
#     "numericCode": "800",
#     "name": "Ugandan shilling",
#     "rate": 2.9235891388709,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 0.34204532596746
#   },
#   "vuv": {
#     "code": "VUV",
#     "alphaCode": "VUV",
#     "numericCode": "548",
#     "name": "Vanuatu vatu",
#     "rate": 0.090149704125996,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 11.092659811755
#   },
#   "wst": {
#     "code": "WST",
#     "alphaCode": "WST",
#     "numericCode": "882",
#     "name": "Samoan tala",
#     "rate": 0.0020691379268282,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 483.29305989423
#   },
#   "xcd": {
#     "code": "XCD",
#     "alphaCode": "XCD",
#     "numericCode": "951",
#     "name": "East Caribbean Dollar",
#     "rate": 0.0020414237460024,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 489.85420197949
#   },
#   "xpf": {
#     "code": "XPF",
#     "alphaCode": "XPF",
#     "numericCode": "953",
#     "name": "CFP Franc",
#     "rate": 0.082750690266243,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 12.084491341191
#   },
#   "yer": {
#     "code": "YER",
#     "alphaCode": "YER",
#     "numericCode": "886",
#     "name": "Yemeni rial",
#     "rate": 0.18852982830719,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 5.3042004492286
#   },
#   "zmw": {
#     "code": "ZMW",
#     "alphaCode": "ZMW",
#     "numericCode": "967",
#     "name": "Zambian kwacha",
#     "rate": 0.019484270250619,
#     "date": "Thu, 21 Mar 2024 23:55:14 GMT",
#     "inverseRate": 51.323451540005
#   }
# }

# %% [markdown]
# ## 파이썬 객체 `rates`의 `type`, 자료(통화)의 수, 각 환율 자료 출력하기
#
# __Sample Run:__
# ```
# <class 'dict'>
# 148
# {'code': 'USD', 'alphaCode': 'USD', 'numericCode': '840', 'name': 'U.S. Dollar', 'rate': 0.00086484208312665, 'date': 'Sat, 4 Sep 2021 23:55:01 GMT', 'inverseRate': 1156.2804580285}
# {'code': 'EUR', 'alphaCode': 'EUR', 'numericCode': '978', 'name': 'Euro', 'rate': 0.00072856130060557, 'date': 'Sat, 4 Sep 2021 23:55:01 GMT', 'inverseRate': 1372.5680998549}
# ...
# ```

# %%
print(type(rates))
print(len(rates))

for rate in rates.values():
    print(rate)
# Out:
# <class 'dict'>
# 146
# {'code': 'AUD', 'alphaCode': 'AUD', 'numericCode': '036', 'name': 'Australian Dollar', 'rate': 0.0011404563098539, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 876.8420073261}
# {'code': 'CAD', 'alphaCode': 'CAD', 'numericCode': '124', 'name': 'Canadian Dollar', 'rate': 0.0010160876357253, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 984.16707854747}
# {'code': 'CNY', 'alphaCode': 'CNY', 'numericCode': '156', 'name': 'Chinese Yuan', 'rate': 0.0054177233448891, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 184.57937704467}
# {'code': 'EUR', 'alphaCode': 'EUR', 'numericCode': '978', 'name': 'Euro', 'rate': 0.00069002910115574, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 1449.2142408561}
# {'code': 'GBP', 'alphaCode': 'GBP', 'numericCode': '826', 'name': 'U.K. Pound Sterling', 'rate': 0.00059054470357732, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 1693.3519070484}
# {'code': 'HKD', 'alphaCode': 'HKD', 'numericCode': '344', 'name': 'Hong Kong Dollar', 'rate': 0.0058862863944225, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 169.8863991646}
# {'code': 'IDR', 'alphaCode': 'IDR', 'numericCode': '360', 'name': 'Indonesian Rupiah', 'rate': 11.805456443962, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.084706593493171}
# {'code': 'INR', 'alphaCode': 'INR', 'numericCode': '356', 'name': 'Indian Rupee', 'rate': 0.06257077601878, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 15.981901833851}
# {'code': 'JPY', 'alphaCode': 'JPY', 'numericCode': '392', 'name': 'Japanese Yen', 'rate': 0.11378271618643, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 8.7886810362436}
# {'code': 'MYR', 'alphaCode': 'MYR', 'numericCode': '458', 'name': 'Malaysian Ringgit', 'rate': 0.00354789898619, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 281.85695362028}
# {'code': 'NZD', 'alphaCode': 'NZD', 'numericCode': '554', 'name': 'New Zealand Dollar', 'rate': 0.0012392891187765, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 806.91420980703}
# {'code': 'PHP', 'alphaCode': 'PHP', 'numericCode': '608', 'name': 'Philippine Peso', 'rate': 0.042127573389606, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 23.737422299446}
# {'code': 'SGD', 'alphaCode': 'SGD', 'numericCode': '702', 'name': 'Singapore Dollar', 'rate': 0.0010086312378278, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 991.44262292884}
# {'code': 'THB', 'alphaCode': 'THB', 'numericCode': '764', 'name': 'Thai Baht', 'rate': 0.027144635137655, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 36.839692076495}
# {'code': 'TWD', 'alphaCode': 'TWD', 'numericCode': '901', 'name': 'New Taiwan Dollar ', 'rate': 0.023992984216366, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 41.678850408191}
# {'code': 'USD', 'alphaCode': 'USD', 'numericCode': '840', 'name': 'U.S. Dollar', 'rate': 0.00075260710505586, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 1328.714535489}
# {'code': 'VND', 'alphaCode': 'VND', 'numericCode': '704', 'name': 'Vietnamese Dong', 'rate': 18.663325353486, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.053581019516075}
# {'code': 'AED', 'alphaCode': 'AED', 'numericCode': '784', 'name': 'U.A.E Dirham', 'rate': 0.0027943019494094, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 357.87113136122}
# {'code': 'BGN', 'alphaCode': 'BGN', 'numericCode': '975', 'name': 'Bulgarian Lev', 'rate': 0.0013494436266574, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 741.046146905}
# {'code': 'BRL', 'alphaCode': 'BRL', 'numericCode': '986', 'name': 'Brazilian Real', 'rate': 0.0037448189081546, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 267.03560960516}
# {'code': 'CHF', 'alphaCode': 'CHF', 'numericCode': '756', 'name': 'Swiss Franc', 'rate': 0.00067410461329376, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 1483.4492752006}
# {'code': 'CZK', 'alphaCode': 'CZK', 'numericCode': '203', 'name': 'Czech Koruna', 'rate': 0.017416442044813, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 57.417008446786}
# {'code': 'DKK', 'alphaCode': 'DKK', 'numericCode': '208', 'name': 'Danish Krone', 'rate': 0.005145845359843, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 194.33152962656}
# {'code': 'EGP', 'alphaCode': 'EGP', 'numericCode': '818', 'name': 'Egyptian Pound', 'rate': 0.035123806676502, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 28.470718143117}
# {'code': 'HUF', 'alphaCode': 'HUF', 'numericCode': '348', 'name': 'Hungarian Forint', 'rate': 0.27143218571125, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 3.6841614688385}
# {'code': 'MDL', 'alphaCode': 'MDL', 'numericCode': '498', 'name': 'Moldova Lei', 'rate': 0.013288862495703, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 75.250985577084}
# {'code': 'MXN', 'alphaCode': 'MXN', 'numericCode': '484', 'name': 'Mexican Peso', 'rate': 0.012602576705436, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 79.348852490513}
# {'code': 'NOK', 'alphaCode': 'NOK', 'numericCode': '578', 'name': 'Norwegian Krone', 'rate': 0.0079828745246461, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 125.26815959748}
# {'code': 'PLN', 'alphaCode': 'PLN', 'numericCode': '985', 'name': 'Polish Zloty', 'rate': 0.0029688103980838, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 336.83525247872}
# {'code': 'RON', 'alphaCode': 'RON', 'numericCode': '946', 'name': 'Romanian New Leu', 'rate': 0.0034315160949082, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 291.41638049836}
# {'code': 'RSD', 'alphaCode': 'RSD', 'numericCode': '941', 'name': 'Serbian Dinar', 'rate': 0.082089504893803, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 12.181825207664}
# {'code': 'RUB', 'alphaCode': 'RUB', 'numericCode': '643', 'name': 'Russian Rouble', 'rate': 0.069186747820647, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 14.453635002361}
# {'code': 'SEK', 'alphaCode': 'SEK', 'numericCode': '752', 'name': 'Swedish Krona', 'rate': 0.0078521261812919, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 127.35404104719}
# {'code': 'TRY', 'alphaCode': 'TRY', 'numericCode': '949', 'name': 'Turkish Lira', 'rate': 0.024103681964391, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 41.487437540759}
# {'code': 'UAH', 'alphaCode': 'UAH', 'numericCode': '980', 'name': 'Ukrainian Hryvnia', 'rate': 0.029307421509451, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 34.121050181011}
# {'code': 'ZAR', 'alphaCode': 'ZAR', 'numericCode': '710', 'name': 'South African Rand', 'rate': 0.0141206649457, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 70.818194741211}
# {'code': 'CLP', 'alphaCode': 'CLP', 'numericCode': '152', 'name': 'Chilean Peso', 'rate': 0.72528960298393, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 1.3787595960095}
# {'code': 'ILS', 'alphaCode': 'ILS', 'numericCode': '376', 'name': 'Israeli New Sheqel', 'rate': 0.0027052461394412, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 369.65213088025}
# {'code': 'ISK', 'alphaCode': 'ISK', 'numericCode': '352', 'name': 'Icelandic Krona', 'rate': 0.10259969665275, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 9.7466175108154}
# {'code': 'AMD', 'alphaCode': 'AMD', 'numericCode': '051', 'name': 'Armenia Dram', 'rate': 0.31116191571349, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 3.2137609054984}
# {'code': 'AZN', 'alphaCode': 'AZN', 'numericCode': '944', 'name': 'Azerbaijan Manat', 'rate': 0.0012791313840985, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 781.78052108761}
# {'code': 'BDT', 'alphaCode': 'BDT', 'numericCode': '050', 'name': 'Bangladeshi taka', 'rate': 0.083656454159061, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 11.953650319659}
# {'code': 'DOP', 'alphaCode': 'DOP', 'numericCode': '214', 'name': 'Dominican Peso', 'rate': 0.044952693496861, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 22.245608042816}
# {'code': 'DZD', 'alphaCode': 'DZD', 'numericCode': '012', 'name': 'Algerian Dinar', 'rate': 0.10322825423821, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 9.6872702864124}
# {'code': 'GEL', 'alphaCode': 'GEL', 'numericCode': '981', 'name': 'Georgian lari', 'rate': 0.0020450867693559, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 488.97680772487}
# {'code': 'IQD', 'alphaCode': 'IQD', 'numericCode': '368', 'name': 'Iraqi dinar', 'rate': 1.0085738472347, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.9914990387088}
# {'code': 'IRR', 'alphaCode': 'IRR', 'numericCode': '364', 'name': 'Iranian rial', 'rate': 32.335861924135, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.030925416565241}
# {'code': 'KGS', 'alphaCode': 'KGS', 'numericCode': '417', 'name': 'Kyrgyzstan Som', 'rate': 0.068844509865645, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 14.525486519573}
# {'code': 'KZT', 'alphaCode': 'KZT', 'numericCode': '398', 'name': 'Kazakhstani Tenge', 'rate': 0.33903554688359, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 2.9495432239834}
# {'code': 'LYD', 'alphaCode': 'LYD', 'numericCode': '434', 'name': 'Libyan Dinar', 'rate': 0.0037193097423798, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 268.86709343013}
# {'code': 'MAD', 'alphaCode': 'MAD', 'numericCode': '504', 'name': 'Moroccan Dirham', 'rate': 0.0077672086419011, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 128.74638059874}
# {'code': 'PKR', 'alphaCode': 'PKR', 'numericCode': '586', 'name': 'Pakistani Rupee', 'rate': 0.21185436118464, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 4.7202238103962}
# {'code': 'SAR', 'alphaCode': 'SAR', 'numericCode': '682', 'name': 'Saudi Riyal', 'rate': 0.0028258572794228, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 353.87491338708}
# {'code': 'TJS', 'alphaCode': 'TJS', 'numericCode': '972', 'name': 'Tajikistan Ruble', 'rate': 0.0084340619563328, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 118.56683116362}
# {'code': 'TMT', 'alphaCode': 'TMT', 'numericCode': '934', 'name': 'New Turkmenistan Manat', 'rate': 0.0026946452455047, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 371.10636424896}
# {'code': 'TND', 'alphaCode': 'TND', 'numericCode': '788', 'name': 'Tunisian Dinar', 'rate': 0.002395988590086, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 417.36425796756}
# {'code': 'UZS', 'alphaCode': 'UZS', 'numericCode': '860', 'name': 'Uzbekistan Sum', 'rate': 9.6213181571028, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.10393586239135}
# {'code': 'JOD', 'alphaCode': 'JOD', 'numericCode': '400', 'name': 'Jordanian Dinar', 'rate': 0.00053365258752656, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 1873.8782934323}
# {'code': 'LBP', 'alphaCode': 'LBP', 'numericCode': '422', 'name': 'Lebanese Pound', 'rate': 67.809900165533, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.01474710916192}
# {'code': 'BYN', 'alphaCode': 'BYN', 'numericCode': '933', 'name': 'Belarussian Ruble', 'rate': 0.0024629445108125, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 406.01807942076}
# {'code': 'XAF', 'alphaCode': 'XAF', 'numericCode': '950', 'name': 'Central African CFA Franc', 'rate': 0.45262482700204, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 2.2093352824314}
# {'code': 'XOF', 'alphaCode': 'XOF', 'numericCode': '952', 'name': 'West African CFA Franc', 'rate': 0.45262482700204, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 2.2093352824314}
# {'code': 'PEN', 'alphaCode': 'PEN', 'numericCode': '604', 'name': 'Peruvian Nuevo Sol', 'rate': 0.0027803652626004, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 359.66497404184}
# {'code': 'ARS', 'alphaCode': 'ARS', 'numericCode': '032', 'name': 'Argentine Peso', 'rate': 0.64294953184098, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 1.5553320291511}
# {'code': 'BOB', 'alphaCode': 'BOB', 'numericCode': '068', 'name': 'Bolivian Boliviano', 'rate': 0.005162884740683, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 193.69016552318}
# {'code': 'COP', 'alphaCode': 'COP', 'numericCode': '170', 'name': 'Colombian Peso', 'rate': 2.9334572390245, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.3408946913208}
# {'code': 'CRC', 'alphaCode': 'CRC', 'numericCode': '188', 'name': 'Costa Rican Colón', 'rate': 0.37939975129908, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 2.6357423708792}
# {'code': 'HTG', 'alphaCode': 'HTG', 'numericCode': '332', 'name': 'Haitian gourde', 'rate': 0.099573476194463, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 10.042835082377}
# {'code': 'PAB', 'alphaCode': 'PAB', 'numericCode': '590', 'name': 'Panamanian Balboa', 'rate': 0.00075260710505586, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 1328.714535489}
# {'code': 'PYG', 'alphaCode': 'PYG', 'numericCode': '600', 'name': 'Paraguayan Guaraní', 'rate': 5.5514889684764, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.18013185393656}
# {'code': 'UYU', 'alphaCode': 'UYU', 'numericCode': '858', 'name': 'Uruguayan Peso', 'rate': 0.028719390002131, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 34.819681056102}
# {'code': 'VES', 'alphaCode': 'VES', 'numericCode': '928', 'name': 'Venezuelan Bolivar', 'rate': 0.02726439410468, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 36.677873572417}
# {'code': 'AFN', 'alphaCode': 'AFN', 'numericCode': '971', 'name': 'Afghan afghani', 'rate': 0.053808710494989, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 18.584351693266}
# {'code': 'ALL', 'alphaCode': 'ALL', 'numericCode': '008', 'name': 'Albanian lek', 'rate': 0.071526181466967, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 13.980894540859}
# {'code': 'ANG', 'alphaCode': 'ANG', 'numericCode': '532', 'name': 'Neth. Antillean Guilder', 'rate': 0.001357994593225, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 736.37995687832}
# {'code': 'AOA', 'alphaCode': 'AOA', 'numericCode': '973', 'name': 'Angolan kwanza', 'rate': 0.64156539436332, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 1.5586875613707}
# {'code': 'AWG', 'alphaCode': 'AWG', 'numericCode': '533', 'name': 'Aruban florin', 'rate': 0.0013637307742292, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 733.28256492945}
# {'code': 'BAM', 'alphaCode': 'BAM', 'numericCode': '977', 'name': 'Bosnia and Herzegovina convertible mark', 'rate': 0.0013614428428496, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 734.51486065104}
# {'code': 'BBD', 'alphaCode': 'BBD', 'numericCode': '052', 'name': 'Barbadian Dollar', 'rate': 0.0015214218624882, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 657.27989366774}
# {'code': 'BHD', 'alphaCode': 'BHD', 'numericCode': '048', 'name': 'Bahrain Dinar', 'rate': 0.00028402618841773, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 3520.8020977602}
# {'code': 'BIF', 'alphaCode': 'BIF', 'numericCode': '108', 'name': 'Burundian franc', 'rate': 2.1554386544296, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.46394268653619}
# {'code': 'BND', 'alphaCode': 'BND', 'numericCode': '096', 'name': 'Brunei Dollar', 'rate': 0.0010124855996022, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 987.66836821469}
# {'code': 'BSD', 'alphaCode': 'BSD', 'numericCode': '044', 'name': 'Bahamian Dollar', 'rate': 0.00075260710505586, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 1328.714535489}
# {'code': 'BWP', 'alphaCode': 'BWP', 'numericCode': '072', 'name': 'Botswana Pula', 'rate': 0.010328606968078, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 96.818477369755}
# {'code': 'BZD', 'alphaCode': 'BZD', 'numericCode': '084', 'name': 'Belize dollar', 'rate': 0.0015188052231374, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 658.41227352002}
# {'code': 'CDF', 'alphaCode': 'CDF', 'numericCode': '976', 'name': 'Congolese franc', 'rate': 2.0908955749446, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.47826396113852}
# {'code': 'CUP', 'alphaCode': 'CUP', 'numericCode': '192', 'name': 'Cuban peso', 'rate': 0.00075260710505586, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 1328.714535489}
# {'code': 'CVE', 'alphaCode': 'CVE', 'numericCode': '132', 'name': 'Cape Verde escudo', 'rate': 0.076987847323601, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 12.989063011422}
# {'code': 'DJF', 'alphaCode': 'DJF', 'numericCode': '262', 'name': 'Djiboutian franc', 'rate': 0.13408923033317, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 7.4577204859427}
# {'code': 'ERN', 'alphaCode': 'ERN', 'numericCode': '232', 'name': 'Eritrean nakfa', 'rate': 0.011360295291791, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 88.025880869717}
# {'code': 'ETB', 'alphaCode': 'ETB', 'numericCode': '230', 'name': 'Ethiopian birr', 'rate': 0.042832040593729, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 23.347008130787}
# {'code': 'FJD', 'alphaCode': 'FJD', 'numericCode': '242', 'name': 'Fiji Dollar', 'rate': 0.0017139662322299, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 583.44206624128}
# {'code': 'GHS', 'alphaCode': 'GHS', 'numericCode': '936', 'name': 'Ghanaian Cedi', 'rate': 0.0097961698062655, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 102.08071315387}
# {'code': 'GIP', 'alphaCode': 'GIP', 'numericCode': '292', 'name': 'Gibraltar pound', 'rate': 0.00059297443381462, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 1686.4133476497}
# {'code': 'GMD', 'alphaCode': 'GMD', 'numericCode': '270', 'name': 'Gambian dalasi', 'rate': 0.051237645829699, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 19.516899806907}
# {'code': 'GNF', 'alphaCode': 'GNF', 'numericCode': '324', 'name': 'Guinean franc', 'rate': 6.4709613052163, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.15453654454615}
# {'code': 'GTQ', 'alphaCode': 'GTQ', 'numericCode': '320', 'name': 'Guatemalan Quetzal', 'rate': 0.0058769349101984, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 170.15672544963}
# {'code': 'GYD', 'alphaCode': 'GYD', 'numericCode': '328', 'name': 'Guyanese dollar', 'rate': 0.15777027195735, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 6.3383296966764}
# {'code': 'HNL', 'alphaCode': 'HNL', 'numericCode': '340', 'name': 'Honduran Lempira', 'rate': 0.01860301143507, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 53.754737693425}
# {'code': 'JMD', 'alphaCode': 'JMD', 'numericCode': '388', 'name': 'Jamaican Dollar', 'rate': 0.11592764654905, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 8.6260700511753}
# {'code': 'KES', 'alphaCode': 'KES', 'numericCode': '404', 'name': 'Kenyan shilling', 'rate': 0.099841254468142, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 10.015899793397}
# {'code': 'KHR', 'alphaCode': 'KHR', 'numericCode': '116', 'name': 'Cambodian riel', 'rate': 3.0513476073377, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.32772405136513}
# {'code': 'KMF', 'alphaCode': 'KMF', 'numericCode': '174', 'name': '\tComoro franc', 'rate': 0.34224621516248, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 2.9218730717746}
# {'code': 'KWD', 'alphaCode': 'KWD', 'numericCode': '414', 'name': 'Kuwaiti Dinar', 'rate': 0.00023174076484366, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 4315.1665641332}
# {'code': 'LAK', 'alphaCode': 'LAK', 'numericCode': '418', 'name': 'Lao kip', 'rate': 15.80276866116, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.063280050568468}
# {'code': 'LKR', 'alphaCode': 'LKR', 'numericCode': '144', 'name': 'Sri Lanka Rupee', 'rate': 0.22932300050564, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 4.3606615899629}
# {'code': 'LRD', 'alphaCode': 'LRD', 'numericCode': '430', 'name': 'Liberian dollar', 'rate': 0.14646468515221, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 6.82758440344}
# {'code': 'LSL', 'alphaCode': 'LSL', 'numericCode': '426', 'name': 'Lesotho loti', 'rate': 0.014277346864576, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 70.041024392362}
# {'code': 'MGA', 'alphaCode': 'MGA', 'numericCode': '969', 'name': 'Malagasy ariary', 'rate': 3.3774196238699, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.29608402608089}
# {'code': 'MKD', 'alphaCode': 'MKD', 'numericCode': '807', 'name': 'Macedonian denar', 'rate': 0.042716869575901, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 23.409955128457}
# {'code': 'MMK', 'alphaCode': 'MMK', 'numericCode': '104', 'name': 'Myanma Kyat', 'rate': 1.582775986094, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.6318013469915}
# {'code': 'MNT', 'alphaCode': 'MNT', 'numericCode': '496', 'name': 'Mongolian togrog', 'rate': 2.561882291485, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.39033799613813}
# {'code': 'MOP', 'alphaCode': 'MOP', 'numericCode': '446', 'name': 'Macanese pataca', 'rate': 0.006074299100992, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 164.62804734734}
# {'code': 'MRU', 'alphaCode': 'MRU', 'numericCode': '929', 'name': 'Mauritanian ouguiya', 'rate': 0.030115607278037, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 33.205373903561}
# {'code': 'MUR', 'alphaCode': 'MUR', 'numericCode': '480', 'name': 'Mauritian Rupee', 'rate': 0.034751458861347, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 28.775770363767}
# {'code': 'MVR', 'alphaCode': 'MVR', 'numericCode': '462', 'name': 'Maldivian rufiyaa', 'rate': 0.011651245811488, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 85.827731744706}
# {'code': 'MWK', 'alphaCode': 'MWK', 'numericCode': '454', 'name': 'Malawian kwacha', 'rate': 1.2684943158514, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.78833620892402}
# {'code': 'MZN', 'alphaCode': 'MZN', 'numericCode': '943', 'name': 'Mozambican metical', 'rate': 0.04811740457725, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 20.782500818276}
# {'code': 'NAD', 'alphaCode': 'NAD', 'numericCode': '516', 'name': 'Namibian dollar', 'rate': 0.014284139132352, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 70.007719102589}
# {'code': 'NGN', 'alphaCode': 'NGN', 'numericCode': '566', 'name': 'Nigerian Naira', 'rate': 1.1085769161102, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.90205739039638}
# {'code': 'NIO', 'alphaCode': 'NIO', 'numericCode': '558', 'name': 'Nicaraguan Córdoba', 'rate': 0.027724155545895, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 36.069628824027}
# {'code': 'NPR', 'alphaCode': 'NPR', 'numericCode': '524', 'name': 'Nepalese Rupee', 'rate': 0.10022451584286, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 9.9775987101588}
# {'code': 'OMR', 'alphaCode': 'OMR', 'numericCode': '512', 'name': 'Omani Rial', 'rate': 0.00029011314997057, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 3446.930965044}
# {'code': 'PGK', 'alphaCode': 'PGK', 'numericCode': '598', 'name': 'Papua New Guinean kina', 'rate': 0.0028403424894716, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 352.07021818909}
# {'code': 'QAR', 'alphaCode': 'QAR', 'numericCode': '634', 'name': 'Qatari Rial', 'rate': 0.0027480560549335, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 363.89359605846}
# {'code': 'RWF', 'alphaCode': 'RWF', 'numericCode': '646', 'name': 'Rwandan franc', 'rate': 0.96886932740251, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 1.0321309300615}
# {'code': 'SBD', 'alphaCode': 'SBD', 'numericCode': '090', 'name': 'Solomon Islands dollar', 'rate': 0.0063331070356895, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 157.90037881321}
# {'code': 'SCR', 'alphaCode': 'SCR', 'numericCode': '690', 'name': 'Seychelles rupee', 'rate': 0.010106112573613, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 98.950015915221}
# {'code': 'SDG', 'alphaCode': 'SDG', 'numericCode': '938', 'name': 'Sudanese pound', 'rate': 0.4523920514721, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 2.2104720822259}
# {'code': 'SOS', 'alphaCode': 'SOS', 'numericCode': '706', 'name': 'Somali shilling', 'rate': 0.43065491187899, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 2.3220448029651}
# {'code': 'SRD', 'alphaCode': 'SRD', 'numericCode': '968', 'name': 'Surinamese dollar', 'rate': 0.026641757281459, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 37.535061574033}
# {'code': 'SSP', 'alphaCode': 'SSP', 'numericCode': '728', 'name': 'South Sudanese pound', 'rate': 1.1938473342427, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.83762803778787}
# {'code': 'STN', 'alphaCode': 'STN', 'numericCode': '930', 'name': 'São Tomé and Príncipe Dobra', 'rate': 0.017186754697312, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 58.184341233218}
# {'code': 'SVC', 'alphaCode': 'SVC', 'numericCode': '222', 'name': 'Salvadoran colon', 'rate': 0.0065960589754403, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 151.60567904614}
# {'code': 'SYP', 'alphaCode': 'SYP', 'numericCode': '760', 'name': 'Syrian pound', 'rate': 9.8121766196746, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.101914186705}
# {'code': 'SZL', 'alphaCode': 'SZL', 'numericCode': '748', 'name': 'Swazi lilangeni', 'rate': 0.014277346864576, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 70.041024392362}
# {'code': 'TOP', 'alphaCode': 'TOP', 'numericCode': '776', 'name': 'Tongan paʻanga', 'rate': 0.0017810689557601, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 561.46057499118}
# {'code': 'TTD', 'alphaCode': 'TTD', 'numericCode': '780', 'name': 'Trinidad Tobago Dollar', 'rate': 0.0051054685353178, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 195.86840915429}
# {'code': 'TZS', 'alphaCode': 'TZS', 'numericCode': '834', 'name': 'Tanzanian shilling', 'rate': 1.92469618309, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.5195625204569}
# {'code': 'UGX', 'alphaCode': 'UGX', 'numericCode': '800', 'name': 'Ugandan shilling', 'rate': 2.9235891388709, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 0.34204532596746}
# {'code': 'VUV', 'alphaCode': 'VUV', 'numericCode': '548', 'name': 'Vanuatu vatu', 'rate': 0.090149704125996, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 11.092659811755}
# {'code': 'WST', 'alphaCode': 'WST', 'numericCode': '882', 'name': 'Samoan tala', 'rate': 0.0020691379268282, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 483.29305989423}
# {'code': 'XCD', 'alphaCode': 'XCD', 'numericCode': '951', 'name': 'East Caribbean Dollar', 'rate': 0.0020414237460024, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 489.85420197949}
# {'code': 'XPF', 'alphaCode': 'XPF', 'numericCode': '953', 'name': 'CFP Franc', 'rate': 0.082750690266243, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 12.084491341191}
# {'code': 'YER', 'alphaCode': 'YER', 'numericCode': '886', 'name': 'Yemeni rial', 'rate': 0.18852982830719, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 5.3042004492286}
# {'code': 'ZMW', 'alphaCode': 'ZMW', 'numericCode': '967', 'name': 'Zambian kwacha', 'rate': 0.019484270250619, 'date': 'Thu, 21 Mar 2024 23:55:14 GMT', 'inverseRate': 51.323451540005}

# %% [markdown]
# ## 환율 정보에서 `code`와 `rate`만 추출하여 출력하기
# __Sample Run:__
# ```
# USD 0.00086484208312665
# EUR 0.00072856130060557
# GBP 0.00062543395312534
# JPY 0.09507474341514
# AUD 0.0011633915091951
# ...
# ```

# %%
for code,info in rates.items():
    
    print(code.upper(), info["rate"])
# Out:
# AUD 0.0011404563098539
# CAD 0.0010160876357253
# CNY 0.0054177233448891
# EUR 0.00069002910115574
# GBP 0.00059054470357732
# HKD 0.0058862863944225
# IDR 11.805456443962
# INR 0.06257077601878
# JPY 0.11378271618643
# MYR 0.00354789898619
# NZD 0.0012392891187765
# PHP 0.042127573389606
# SGD 0.0010086312378278
# THB 0.027144635137655
# TWD 0.023992984216366
# USD 0.00075260710505586
# VND 18.663325353486
# AED 0.0027943019494094
# BGN 0.0013494436266574
# BRL 0.0037448189081546
# CHF 0.00067410461329376
# CZK 0.017416442044813
# DKK 0.005145845359843
# EGP 0.035123806676502
# HUF 0.27143218571125
# MDL 0.013288862495703
# MXN 0.012602576705436
# NOK 0.0079828745246461
# PLN 0.0029688103980838
# RON 0.0034315160949082
# RSD 0.082089504893803
# RUB 0.069186747820647
# SEK 0.0078521261812919
# TRY 0.024103681964391
# UAH 0.029307421509451
# ZAR 0.0141206649457
# CLP 0.72528960298393
# ILS 0.0027052461394412
# ISK 0.10259969665275
# AMD 0.31116191571349
# AZN 0.0012791313840985
# BDT 0.083656454159061
# DOP 0.044952693496861
# DZD 0.10322825423821
# GEL 0.0020450867693559
# IQD 1.0085738472347
# IRR 32.335861924135
# KGS 0.068844509865645
# KZT 0.33903554688359
# LYD 0.0037193097423798
# MAD 0.0077672086419011
# PKR 0.21185436118464
# SAR 0.0028258572794228
# TJS 0.0084340619563328
# TMT 0.0026946452455047
# TND 0.002395988590086
# UZS 9.6213181571028
# JOD 0.00053365258752656
# LBP 67.809900165533
# BYN 0.0024629445108125
# XAF 0.45262482700204
# XOF 0.45262482700204
# PEN 0.0027803652626004
# ARS 0.64294953184098
# BOB 0.005162884740683
# COP 2.9334572390245
# CRC 0.37939975129908
# HTG 0.099573476194463
# PAB 0.00075260710505586
# PYG 5.5514889684764
# UYU 0.028719390002131
# VES 0.02726439410468
# AFN 0.053808710494989
# ALL 0.071526181466967
# ANG 0.001357994593225
# AOA 0.64156539436332
# AWG 0.0013637307742292
# BAM 0.0013614428428496
# BBD 0.0015214218624882
# BHD 0.00028402618841773
# BIF 2.1554386544296
# BND 0.0010124855996022
# BSD 0.00075260710505586
# BWP 0.010328606968078
# BZD 0.0015188052231374
# CDF 2.0908955749446
# CUP 0.00075260710505586
# CVE 0.076987847323601
# DJF 0.13408923033317
# ERN 0.011360295291791
# ETB 0.042832040593729
# FJD 0.0017139662322299
# GHS 0.0097961698062655
# GIP 0.00059297443381462
# GMD 0.051237645829699
# GNF 6.4709613052163
# GTQ 0.0058769349101984
# GYD 0.15777027195735
# HNL 0.01860301143507
# JMD 0.11592764654905
# KES 0.099841254468142
# KHR 3.0513476073377
# KMF 0.34224621516248
# KWD 0.00023174076484366
# LAK 15.80276866116
# LKR 0.22932300050564
# LRD 0.14646468515221
# LSL 0.014277346864576
# MGA 3.3774196238699
# MKD 0.042716869575901
# MMK 1.582775986094
# MNT 2.561882291485
# MOP 0.006074299100992
# MRU 0.030115607278037
# MUR 0.034751458861347
# MVR 0.011651245811488
# MWK 1.2684943158514
# MZN 0.04811740457725
# NAD 0.014284139132352
# NGN 1.1085769161102
# NIO 0.027724155545895
# NPR 0.10022451584286
# OMR 0.00029011314997057
# PGK 0.0028403424894716
# QAR 0.0027480560549335
# RWF 0.96886932740251
# SBD 0.0063331070356895
# SCR 0.010106112573613
# SDG 0.4523920514721
# SOS 0.43065491187899
# SRD 0.026641757281459
# SSP 1.1938473342427
# STN 0.017186754697312
# SVC 0.0065960589754403
# SYP 9.8121766196746
# SZL 0.014277346864576
# TOP 0.0017810689557601
# TTD 0.0051054685353178
# TZS 1.92469618309
# UGX 2.9235891388709
# VUV 0.090149704125996
# WST 0.0020691379268282
# XCD 0.0020414237460024
# XPF 0.082750690266243
# YER 0.18852982830719
# ZMW 0.019484270250619

# %% [markdown]
# ## `code`를 key, `rate`를 value로 하는 dict type의 `krw_rates` 만들기
# - 위의 코드를 수정하여 새로운 dict type의 객체 `krw_rates`를 만들어 `key`로 `rate`를 쉽게 찾는데 활용하려고 합니다.
# - 즉 `krw_rates['USD']`의 형식을 사용하여 환율 정보를 쉽게 접근할 수 있도록 하는 작업입니다.
# - 다른 말로, 위에서 출력해본 `code, rate` 정보를 모두 `krw_rates`에 저장하는 것입니다.
#
# __Sample Run:__
# ```
# USD: 0.00076447912070859
# EUR: 0.00071372779815721
# JPY: 0.10051437371601
# CAD: 0.0010456669770955
# ```

# %%
krw_rates = dict()   # empty name in dict type 

for code, info in rates.items():
    krw_rates[code.upper()] = info["rate"]

print('USD:', krw_rates['USD']) 
print('EUR:', krw_rates['EUR'])
print('JPY:', krw_rates['JPY'])
print('CAD:', krw_rates['CAD'])
# Out:
# USD: 0.00075260710505586
# EUR: 0.00069002910115574
# JPY: 0.11378271618643
# CAD: 0.0010160876357253

# %% [markdown]
# ## 환율 계산 하기
# 거의 다 했습니다. 이제 환율을 계산해봅니다. 여기서 제공되는 환율은 Korean Won(KRW)으로 1원에 대한 다른 통화의 가격입니다. 그러므로, 대개 숫자가 낮은 값으로 출력됨으로, 1000원에 대한 환율을 계산하여 봅시다.
# - `krw_rates[]`로 출력되는 값들은 모두 문자열(`str`) 타입이므로 `float()`로 변환하는 것이 필요합니다.
#
# __Sample Run:__
# ```
# 0.86484208312665
# 0.72856130060557
# 95.07474341513999
# 1.084071583917
# ```

# %%
print('USD:', float(krw_rates['USD']) * 1000)
print('EUR:', float(krw_rates['EUR']) * 1000)
print('JPY:', float(krw_rates['JPY']) * 1000)
print('CAD:', float(krw_rates['CAD']) * 1000)
# Out:
# USD: 0.75260710505586
# EUR: 0.69002910115574
# JPY: 113.78271618643001
# CAD: 1.0160876357253

# %% [markdown]
# ## 환율 정보에서 `date`를 추출하여 `krw_rates`에 추가하기
# - 환율 정보에서 빼놓을 수 없는 정보는 `date`입니다. `rate`와 더불어 `date`정보를 추가하려고 합니다. `krw_rates`의 `key`는 변함없이 각 통화 `code`값들(e.g. 'USD', 'EUR', etc.)이지만, `value`로 `rate`뿐만 아니라 `date`를 포함하여 정보를 유지관리하고 보호하려고 합니다. 다음과 같은 dict type을 만들려고 하는 것입니다. 이것을 어떻게 구현할 수 있겠습니까?
#
# ```
# {
#   'USD': ('Sat, 4 Sep 2021 23:55:01 GMT', '0.00086484208312665'),
#   'EUR': ('Sat, 4 Sep 2021 23:55:01 GMT', '0.00072856130060557'),
#  ...
# }
# ```
# 값이 여러 개일 경우에는 list, tuple, dict types을 사용하여 하나로 묶어야 합니다. 자료를 수정하지 아니하도록 여기서는 tuple을 사용하도록 합니다.
#
# __Sample Run:__
# ```
# Sat, 4 Sep 2021 23:55:01 GMT 0.86484208312665
# Sat, 4 Sep 2021 23:55:01 GMT 0.72856130060557
# Sat, 4 Sep 2021 23:55:01 GMT 95.07474341513999
# Sat, 4 Sep 2021 23:55:01 GMT 1.084071583917
# ```

# %%
krw_rates = dict()   # empty name in dict type, krw_rates = {}

for code, info in rates.items():
    krw_rates[code.upper()] = (info['date'], info['rate'])

print('USD:', krw_rates['USD'][1], krw_rates['USD'][0])
print('EUR:', krw_rates['EUR'][1], krw_rates['EUR'][0])
print('JPY:', krw_rates['JPY'][1], krw_rates['JPY'][0])
print('CAD:', krw_rates['CAD'][1], krw_rates['CAD'][0])
# Out:
# USD: 0.00075260710505586 Thu, 21 Mar 2024 23:55:14 GMT
# EUR: 0.00069002910115574 Thu, 21 Mar 2024 23:55:14 GMT
# JPY: 0.11378271618643 Thu, 21 Mar 2024 23:55:14 GMT
# CAD: 0.0010160876357253 Thu, 21 Mar 2024 23:55:14 GMT

# %% [markdown]
# --------
# 슬기로운 자는 재앙을 보면 숨어 피하여도 어리석은 자들은 나가다가 해를 받느니라.
# 잠언22:3, 27:12
